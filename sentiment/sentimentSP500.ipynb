# %%
import eikon as ek
import numpy as np
import pandas as pd
from eikon import EikonError
import datetime
import time
ek.set_app_key('f01a5002bf4649578cf705c13f7d30d9bdcf2c9d')

# %%
filePath = r'C:\Users\Keavan\Jupyter\Momentum\sentiment\data'

# %%
start = '2020-01-01'
end = datetime.datetime.today().strftime('%Y-%m-%d')

# %%
data = ek.get_timeseries('.SPX', interval='tick', start_date = start, end_date = end)

# %%
data = data.dropna()

# %%
data.plot(figsize=(8,5))

# %%
data = data[data['VALUE'] != 0]

# %%
data.plot(figsize=(8,5))
