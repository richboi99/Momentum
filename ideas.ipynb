# %% [markdown]
# ## Trades
# - short CCO.TO call spreads - not very profitable
# - long long dated USO calls
#
# Quantify the long-term oil price that Saudi and Russia need to break-even - how long can these countries sustain the price war??

# %%
import eikon as ek
import numpy as np
import pandas as pd
import pandas_datareader as web
from eikon import EikonError
import datetime
import matplotlib.pyplot as plt
import time
ek.set_app_key('f01a5002bf4649578cf705c13f7d30d9bdcf2c9d')

# %%
fileDir = r'C:\Users\Keavan\Jupyter\Trading'

# %%
start = '1980-01-01'
end = datetime.datetime.today().strftime('%Y-%m-%d')

# %%
index = pd.date_range(start, end)
df = pd.DataFrame(index=index)

# %%
df = web.DataReader('DCOILWTICO', 'fred', start, end)
df = df.rename(columns={'DCOILWTICO':'WTI'})

# %%
df.plot(figsize=(8,5))

# %%
df.insert(loc=0, column = 'USO', value = web.DataReader('USO', 'yahoo', '2006-04-01', end)['Adj Close'])

# %%
df.plot(figsize=(8,5))

# %%
web.DataReader('USO', 'yahoo', '2006-04-01', end)['Adj Close']
# Out:
# Date
# 2006-04-10    68.019997
# 2006-04-11    68.199997
# 2006-04-12    67.839996
# 2006-04-13    68.820000
# 2006-04-17    69.790001
#                 ...
# 2020-03-06     8.730000
# 2020-03-09     6.520000
# 2020-03-10     7.240000
# 2020-03-11     6.940000
# 2020-03-12     6.540000
# Name: Adj Close, Length: 3505, dtype: float64

# %%
sa = web.DataReader('GGNLBASAA188N', 'fred', start, end)

# %%
sa.insert(loc=0, column = 'crudeProduction', value = web.DataReader('SAUNGDPMOMBD', 'fred', start, end))

# %%
sa.plot(figsize=(8,5))

# %%
fig, ax = plt.subplots(figsize=(15,10))

ax.plot(sa.index, sa['GGNLBASAA188N'], 'blue')

ax2 = ax.twinx()

ax2.plot(sa.index, sa['crudeProduction'], 'red')
